# %%
#importing all necessary libraries:
import pandas as pd
import numpy as np 
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button
import matplotlib.ticker as mticker
import scipy
import os 
from sympy import symbols, diff
from reproduce_code import *
import tensorflow as tf

# %%
fname = '0.75Pa15p_cleared.csv'

# %%
'''
tf.config.set_visible_devices(devices, device_type) controls which physical hardware TensorFlow is allowed to see and allocate memory on.

In the below command we by giving deivce list as an empty set we preeety much are telling it to act as if there are no GPUs in the system.

'''
tf.config.set_visible_devices([], 'GPU')

# %%
val_begin =[.4]
tau = 16
nparticles = 15
ndim = 4
